# %% [markdown]
# <a href="https://colab.research.google.com/github/autorarosana/Fatec-Algoritmos-1/blob/main/Cap03_RosanaSantos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bit é a menor unidade de armazenamento de um computador. Seus valores podem ser 1 ou 0.
# Byte é equivalenjte a 8 bits e permite fazer 256 combinações (de 0 NA 255)
#
# EM 5 BYTES EXISTEM 40 BITS

# %%
numeros = [13, 42, 7, 100, 255]
for n in numeros:
 print(f'{n:3d} -> {bin(n)} -> {n:08b}')
# Out:
#  13 -> 0b1101 -> 00001101
#  42 -> 0b101010 -> 00101010
#   7 -> 0b111 -> 00000111
# 100 -> 0b1100100 -> 01100100
# 255 -> 0b11111111 -> 11111111

# %%
44100 * 2 * 2
176400 * 600
105840000 / 1048576
# Out:
# 100.9368896484375

# %%
largura = 1920
altura = 1080
tamanho = largura * altura * 3
print(tamanho)
# Out:
# 6220800

# %%
largura = 1920
altura = 1080
bytes_por_pixel = 3
tamanho_bytes = largura * altura * bytes_por_pixel

NAO ENTENDI ISSO

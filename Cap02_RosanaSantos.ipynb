# %% [markdown]
# <a href="https://colab.research.google.com/github/autorarosana/Fatec-Algoritmos-1/blob/main/Cap02_RosanaSantos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Complete as frases abaixo: a) Um bit pode assumir os valores __0_ ou _1__. b) Um byte
# possui _8__ bits. c) Com 8 bits, é possível formar __256_ combinações diferentes. d) A função
# ord() transforma um caractere em _número__. e) A função chr() transforma um número em letra___.

# %% [markdown]
#  cada código decimal: 65, 68, 80, 90 e 83
#  65 A
#  68 D
#  80 P
#  90 Z
#  83 S

# %% [markdown]
# NÃO ENTENDI O EXERCÍCIO 4

# %%
print (chr(67))
print (chr(68))
print (chr(78))
# Out:
# C
# D
# N

# %%
palavra = 'LOVE'

for letra in palavra:
# Out:
#   File "/tmp/ipykernel_1843/568547966.py", line 5
#
#     ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# 128000bits/s X 180s = 23040000bits
# 23040000 / 8 = 28880000 bytes
# 2880000 / 1000 = 2.88 MB

# %%
taxa_kbps = 128
tempo-min = 3

taxa-bps = taxa_kbps * 1000
tempo_seg = tempo_min * 60

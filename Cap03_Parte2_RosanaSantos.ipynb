# %% [markdown]
# <a href="https://colab.research.google.com/github/autorarosana/Fatec-Algoritmos-1/blob/main/Cap03_Parte2_RosanaSantos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Rosana Aparecida dos Santos
RA 3011542623023
"Sobre mim"
Sou uma senhora curiosa e cansada. Após décadas sendo jornalista, mãe e professora me cansei de sentir tanto peso do mundo e resovi trocar a área de humanas por exatas. Cansei de subjetividades. Quero a simplicidade dos números, a lógica do computador.


"O que aprendi sobre bits"
Aprendi o suficiente para entender porque nos deixamos enganar pela propagando enganosa das operadoras de telefone e ainda não entendi o suficiente para entender porque a internet no Brasil é tão pior do que a do Reino Unido.
Aprendi que um bit é a menor unidade de informação computacional e um byte compreende 8 bits.
Um KByte é 1024 Bytes.
Um MByte é 1024 KBytes.
Um GByte é 1024 MBytes.
Um pixel tem tres dimensoes.

Ainda estou confusa quanto aos cálculos em Bytes, KB ou MB para som.
Gostei de saber como letras e números se transformam em 0 e 1.
A divisão binária e a tabela ASC

Estou me esforcando para aprender a criar os códigos como sugerido no exercício 11 do capítulo 3.
Estou aprendendo bastante, mas me falta letramento digital. HELP
Não é só sobre Python, é sobre trocar aquivo pelo Google Drive, usar Git Hub, saber o que é Canvas, Notion...

# %%
numero = 65
binario = bin(numero)
print(binario)
# Out:
# 0b1000001

# %%
largura = 1200
altura = 800
canais = 3
bytes_por_canal = 1

pixels = largura * altura
tamanho_bytes = pixels * canais * bytes_por_canal
tamanho_MB = tamanho_bytes / (1024 * 1024)

print("Quantidade_de_pixels:", pixels)
print("Tamanho_em_bytes:", tamanho_bytes)
print("Tamanho_em_MB:", tamanho_MB)
# Out:
# Quantidade_de_pixels: 960000
# Tamanho_em_bytes: 2880000
# Tamanho_em_MB: 2.74658203125

# %%
duracao_minutos = 5
taxa_amostragem = 44100
bits_por_amostra = 16
canais = 2
duracao_segundos = duracao_minutos * 60
total_bits = duracao_segundos * taxa_amostragem * bits_por_amostra * canais
total_bytes = total_bits / 8
tamanho_MB = total_bytes  / (1024 * 1024)
print ("Duração em segundos:", duracao_segundos)
print ("Tamanho_em_bytes:", total_bits)
print ("Tamanho_em_MB:", tamanho_MB)
# Out:
# Duração em segundos: 300
# Tamanho_em_bytes: 423360000
# Tamanho_em_MB: 50.46844482421875

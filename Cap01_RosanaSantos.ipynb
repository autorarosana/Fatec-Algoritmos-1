# %%
print ("Rosana dos Santos")
# Out:
# Rosana dos Santos

# %%
print ("RA 3011542623023")
# Out:
# RA 3011542623023

# %%
print ("Um dia a gente aprende")
# Out:
# Um dia a gente aprende

# %% [markdown]
# Meu nome é Rosana Aparecida dos Santos e estou iniciando minha jornada para tornar-me cientista de Dados.

# %%
print ("esses sao meus primeiros exercicios")
# Out:
# esses sao meus primeiros exercicios

# %%
print ("Nome: Rosana dos Santos")
print ("Curso:Ciência de Dados para Negócios")
print ("Disciplina: Algoritmos e Programação com IA")
print ("Meta: aprender a resolver problemas com programação")
# Out:
# Nome: Rosana dos Santos
# Curso:Ciência de Dados para Negócios
# Disciplina: Algoritmos e Programação com IA
# Meta: aprender a resolver problemas com programação

# %%
print ("Curso Ciencia de Dados")
print ("Bem Vindo ao mundo Python")
print ("Um comando de cada vez")
print ("Voce consegue!!!")
# Out:
# Curso Ciencia de Dados
# Bem Vindo ao mundo Python
# Um comando de cada vez
# Voce consegue!!!

# %%
print ("Curso CDN - linguagem Python")
print ("Primeiros exercicios")

print ("Hora de aprender Python")
print ("Vamos fazer acontecer")

print ("CDN 001 / Python")
print ("Treino orientado")
# Out:
# Curso CDN - linguagem Python
# Primeiros exercicios
# Hora de aprender Python
# Vamos fazer acontecer
# CDN 001 / Python
# Treino orientado
